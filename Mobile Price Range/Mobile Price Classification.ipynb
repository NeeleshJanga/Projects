# %% [markdown]
# # Mobile Price Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading Dataset

# %%
testdf = pd.read_csv("test.csv")
traindf = pd.read_csv("train.csv")

# %%
traindf.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
# 5        164        1  ...       1004      1654  1067    17     1         10
# 6        139        8  ...        381      1018  3220    13     8         18
# 7        187        4  ...        512      1149   700    16     3          5
# 8        174        7  ...        386       836  1099    17     1         20
# 9         93        5  ...       1137      1224   513    19    10         12
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
# 5        1             0     0            1
# 6        1             0     1            3
# 7        1             1     1            0
# 8        1             0     0            0
# 9        1             0     0            0
#
# [10 rows x 21 columns]

# %%
testdf.head(10)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
# 5   6           1464     1          2.9         1   5       1          50
# 6   7           1718     0          2.4         0   1       0          47
# 7   8            833     0          2.4         1   0       0          62
# 8   9           1111     1          2.9         1   9       1          25
# 9  10           1520     0          0.5         0   1       0          25
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
# 5    0.8        198  ...   9        569       939  3506    10     7
# 6    1.0        156  ...   3       1283      1374  3873    14     2
# 7    0.8        111  ...   2       1312      1880  1495     7     2
# 8    0.6        101  ...  19        556       876  3485    11     9
# 9    0.5        171  ...  20         52      1009   651     6     0
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
# 5          3        1             1     1
# 6         10        0             0     0
# 7         18        0             1     1
# 8         10        1             1     0
# 9          5        1             0     1
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Data Pre-processing

# %%
print(traindf['px_height'].all())
# Out:
# False

# %%
traindf['px_height'].replace(0, traindf['px_height'].mean(), inplace=True)

# %%
print(traindf['px_height'].all())
# Out:
# True

# %% [markdown]
# ### >> Feature Extraction

# %%
traindf['px_size'] = np.round((traindf['px_height'] * traindf['px_width']), 2)
traindf.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...       756  2549     9     7         19        0
# 1        136        3  ...      1988  2631    17     3          7        1
# 2        145        5  ...      1716  2603    11     2          9        1
# 3        131        6  ...      1786  2769    16     8         11        1
# 4        141        2  ...      1212  1411     8     2         15        1
#
#    touch_screen  wifi  price_range    px_size
# 0             0     1            1    15120.0
# 1             1     0            2  1799140.0
# 2             1     0            2  2167308.0
# 3             0     0            2  2171776.0
# 4             1     0            1  1464096.0
#
# [5 rows x 22 columns]

# %%
traindf['px_size'] = traindf['px_size'] / 926

# %%
traindf.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...       756  2549     9     7         19        0
# 1        136        3  ...      1988  2631    17     3          7        1
# 2        145        5  ...      1716  2603    11     2          9        1
# 3        131        6  ...      1786  2769    16     8         11        1
# 4        141        2  ...      1212  1411     8     2         15        1
#
#    touch_screen  wifi  price_range      px_size
# 0             0     1            1    16.328294
# 1             1     0            2  1942.915767
# 2             1     0            2  2340.505400
# 3             0     0            2  2345.330454
# 4             1     0            1  1581.097192
#
# [5 rows x 22 columns]

# %% [markdown]
# ### >> Feature Selection

# %%
testdf.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
ids = testdf['id'] 
testdf.drop('id', inplace=True, axis=1)

# %%
traindf.drop(labels=['blue', 'dual_sim', 'm_dep', 'mobile_wt', 'talk_time', 'px_height', 'px_width'], inplace=True, axis=1)
testdf.drop(labels=['blue', 'dual_sim', 'm_dep', 'mobile_wt', 'talk_time', 'px_height', 'px_width'], inplace=True, axis=1)

# %%
print(traindf['sc_h'].all())
print(traindf['sc_w'].all())
# Out:
# True
# False

# %%
traindf['sc_w'].replace(0, int(traindf['sc_w'].mean()), inplace=True)

# %%
print(traindf['sc_w'].all())
# Out:
# True

# %%
traindf['sc_size'] = np.round((traindf['sc_h'] * traindf['sc_w']), 2)
traindf.drop(['sc_h', 'sc_w'], axis=1, inplace=True)

# %%
traindf.head(10)
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0            842          2.2   1       0           7        2   2  2549
# 1           1021          0.5   0       1          53        3   6  2631
# 2            563          0.5   2       1          41        5   6  2603
# 3            615          2.5   0       0          10        6   9  2769
# 4           1821          1.2  13       1          44        2  14  1411
# 5           1859          0.5   3       0          22        1   7  1067
# 6           1821          1.7   4       1          10        8  10  3220
# 7           1954          0.5   0       0          24        4   0   700
# 8           1445          0.5   0       0          53        7  14  1099
# 9            509          0.6   2       1           9        5  15   513
#
#    three_g  touch_screen  wifi  price_range      px_size  sc_size
# 0        0             0     1            1    16.328294       63
# 1        1             1     0            2  1942.915767       51
# 2        1             1     0            2  2340.505400       22
# 3        1             0     0            2  2345.330454      128
# 4        1             1     0            1  1581.097192       16
# 5        1             0     0            1  1793.321814       17
# 6        1             0     1            3   418.853132      104
# 7        1             1     1            0   635.300216       48
# 8        1             0     0            0   348.483801       17
# 9        1             0     0            0  1502.902808      190

# %%
traindf.shape
# Out:
# (2000, 14)

# %%
traindf.all()
# Out:
# battery_power     True
# clock_speed       True
# fc               False
# four_g           False
# int_memory        True
# n_cores           True
# pc               False
# ram               True
# three_g          False
# touch_screen     False
# wifi             False
# price_range      False
# px_size           True
# sc_size           True
# dtype: bool

# %%
traindf['pc'].replace(0, np.round(traindf['pc'].mean(), 0), inplace=True)

# %%
traindf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0            842          2.2   1       0           7        2   2  2549
# 1           1021          0.5   0       1          53        3   6  2631
# 2            563          0.5   2       1          41        5   6  2603
# 3            615          2.5   0       0          10        6   9  2769
# 4           1821          1.2  13       1          44        2  14  1411
#
#    three_g  touch_screen  wifi  price_range      px_size  sc_size
# 0        0             0     1            1    16.328294       63
# 1        1             1     0            2  1942.915767       51
# 2        1             1     0            2  2340.505400       22
# 3        1             0     0            2  2345.330454      128
# 4        1             1     0            1  1581.097192       16

# %%
traindf['pc'].head()
# Out:
# 0     2
# 1     6
# 2     6
# 3     9
# 4    14
# Name: pc, dtype: int64

# %%
traindf.all()
# Out:
# battery_power     True
# clock_speed       True
# fc               False
# four_g           False
# int_memory        True
# n_cores           True
# pc                True
# ram               True
# three_g          False
# touch_screen     False
# wifi             False
# price_range      False
# px_size           True
# sc_size           True
# dtype: bool

# %%
traindf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0            842          2.2   1       0           7        2   2  2549
# 1           1021          0.5   0       1          53        3   6  2631
# 2            563          0.5   2       1          41        5   6  2603
# 3            615          2.5   0       0          10        6   9  2769
# 4           1821          1.2  13       1          44        2  14  1411
#
#    three_g  touch_screen  wifi  price_range      px_size  sc_size
# 0        0             0     1            1    16.328294       63
# 1        1             1     0            2  1942.915767       51
# 2        1             1     0            2  2340.505400       22
# 3        1             0     0            2  2345.330454      128
# 4        1             1     0            1  1581.097192       16

# %%
testdf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0           1043          1.8  14       0           5        3  16  3476
# 1            841          0.5   4       1          61        5  12  3895
# 2           1807          2.8   1       0          27        3   4  2396
# 3           1546          0.5  18       1          25        8  20  3893
# 4           1434          1.4  11       1          49        6  18  1773
#
#    sc_h  sc_w  three_g  touch_screen  wifi
# 0    12     7        0             1     0
# 1     6     0        1             0     0
# 2    17    10        0             1     1
# 3    10     0        1             1     0
# 4    15     8        1             0     1

# %%
testdf['sc_w'].replace(0, int(testdf['sc_w'].mean()), inplace=True)

# %%
print(testdf['sc_w'].all())
# Out:
# True

# %%
print(testdf['sc_h'].all())
# Out:
# True

# %%
testdf['sc_size'] = np.round((testdf['sc_h'] * testdf['sc_w']), 0)
testdf.drop(['sc_h', 'sc_w'], axis=1, inplace=True)

# %%
testdf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0           1043          1.8  14       0           5        3  16  3476
# 1            841          0.5   4       1          61        5  12  3895
# 2           1807          2.8   1       0          27        3   4  2396
# 3           1546          0.5  18       1          25        8  20  3893
# 4           1434          1.4  11       1          49        6  18  1773
#
#    three_g  touch_screen  wifi  sc_size
# 0        0             1     0       84
# 1        1             0     0       30
# 2        0             1     1      170
# 3        1             1     0       50
# 4        1             0     1      120

# %%
traindf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0            842          2.2   1       0           7        2   2  2549
# 1           1021          0.5   0       1          53        3   6  2631
# 2            563          0.5   2       1          41        5   6  2603
# 3            615          2.5   0       0          10        6   9  2769
# 4           1821          1.2  13       1          44        2  14  1411
#
#    three_g  touch_screen  wifi  price_range      px_size  sc_size
# 0        0             0     1            1    16.328294       63
# 1        1             1     0            2  1942.915767       51
# 2        1             1     0            2  2340.505400       22
# 3        1             0     0            2  2345.330454      128
# 4        1             1     0            1  1581.097192       16

# %%
traindf.drop(['px_size'], axis=1, inplace=True)

# %%
traindf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0            842          2.2   1       0           7        2   2  2549
# 1           1021          0.5   0       1          53        3   6  2631
# 2            563          0.5   2       1          41        5   6  2603
# 3            615          2.5   0       0          10        6   9  2769
# 4           1821          1.2  13       1          44        2  14  1411
#
#    three_g  touch_screen  wifi  price_range  sc_size
# 0        0             0     1            1       63
# 1        1             1     0            2       51
# 2        1             1     0            2       22
# 3        1             0     0            2      128
# 4        1             1     0            1       16

# %%
testdf.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0           1043          1.8  14       0           5        3  16  3476
# 1            841          0.5   4       1          61        5  12  3895
# 2           1807          2.8   1       0          27        3   4  2396
# 3           1546          0.5  18       1          25        8  20  3893
# 4           1434          1.4  11       1          49        6  18  1773
#
#    three_g  touch_screen  wifi  sc_size
# 0        0             1     0       84
# 1        1             0     0       30
# 2        0             1     1      170
# 3        1             1     0       50
# 4        1             0     1      120

# %%
testdf.shape
# Out:
# (1000, 12)

# %%
traindf.shape
# Out:
# (2000, 13)

# %% [markdown]
# ### y_train

# %%
y_train = traindf['price_range']
traindf.drop(['price_range'], inplace=True, axis=1)

# %%
y_train.shape
# Out:
# (2000,)

# %%
y_train = pd.DataFrame(y_train)

# %%
y_train.head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# ### X_train

# %%
X_train = traindf

# %%
X_train.shape
# Out:
# (2000, 12)

# %%
X_train.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0            842          2.2   1       0           7        2   2  2549
# 1           1021          0.5   0       1          53        3   6  2631
# 2            563          0.5   2       1          41        5   6  2603
# 3            615          2.5   0       0          10        6   9  2769
# 4           1821          1.2  13       1          44        2  14  1411
#
#    three_g  touch_screen  wifi  sc_size
# 0        0             0     1       63
# 1        1             1     0       51
# 2        1             1     0       22
# 3        1             0     0      128
# 4        1             1     0       16

# %% [markdown]
# ### X_test

# %%
X_test = testdf

# %%
X_test.shape
# Out:
# (1000, 12)

# %%
X_test.head()
# Out:
#    battery_power  clock_speed  fc  four_g  int_memory  n_cores  pc   ram  \
# 0           1043          1.8  14       0           5        3  16  3476
# 1            841          0.5   4       1          61        5  12  3895
# 2           1807          2.8   1       0          27        3   4  2396
# 3           1546          0.5  18       1          25        8  20  3893
# 4           1434          1.4  11       1          49        6  18  1773
#
#    three_g  touch_screen  wifi  sc_size
# 0        0             1     0       84
# 1        1             0     0       30
# 2        0             1     1      170
# 3        1             1     0       50
# 4        1             0     1      120

# %% [markdown]
# ## Cross Validation using different Classification Algorithms to select best model

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
accuracyDetails = {}

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ### Random Forest's Cross validation

# %%
model = RandomForestClassifier(n_estimators = 40)
scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
print(scores*100)
# Out:
# [79.  78.  81.  82.5 80.  79.  82.5 83.  80.5 78. ]

# %%
print("Mean Accuracy for the Model using Random Forest = {}".format(np.round(scores.mean()*100, 2)))
# Out:
# Mean Accuracy for the Model using Random Forest = 80.35

# %%
accuracyDetails['Random Forest'] = np.round(scores.mean()*100, 2)

# %% [markdown]
# ### SVM's Cross validation

# %%
model = SVC()
scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
print(scores*100)
# Out:
# [78.  79.  84.  86.5 78.5 81.  86.  83.5 81.5 82.5]

# %%
print("Mean Accuracy for the Model using SVM = {}".format(np.round(scores.mean()*100, 2)))
# Out:
# Mean Accuracy for the Model using SVM = 82.05

# %%
accuracyDetails['SVM'] = np.round(scores.mean()*100, 2)

# %% [markdown]
# ### KNN's Cross validation

# %%
model = KNeighborsClassifier(n_neighbors=7)
scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
print(scores*100)
# Out:
# [77.5 77.  81.5 83.5 78.5 83.  82.  78.  83.5 79.5]

# %%
print("Mean Accuracy for the Model using KNN = {}".format(np.round(scores.mean()*100, 2)))
# Out:
# Mean Accuracy for the Model using KNN = 80.4

# %%
accuracyDetails['KNN'] = np.round(scores.mean()*100, 2)

# %% [markdown]
# ### Logistic Regression's Cross validation

# %%
model = LogisticRegression(solver='liblinear')
scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
print(scores*100)
# Out:
# [71.  75.5 71.  80.  75.5 67.5 75.  77.5 72.5 70. ]

# %%
print("Mean Accuracy for the Model using Logistic Regression = {}".format(np.round(scores.mean()*100, 2)))
# Out:
# Mean Accuracy for the Model using Logistic Regression = 73.55

# %%
accuracyDetails['Logistic Regression'] = np.round(scores.mean()*100, 2)

# %%
print(accuracyDetails)
# Out:
# {'Random Forest': 80.35, 'SVM': 82.05, 'KNN': 80.4, 'Logistic Regression': 73.55}

# %% [markdown]
# # Using Support Vector Machine for Predictions

# %%
SVM = SVC()
SVM.fit(X_train, y_train['price_range'])
# Out:
# SVC()

# %%
y_pred = SVM.predict(X_test)

# %%
df_y_pred = pd.DataFrame(y_pred)

# %%
df_y_pred.head()
# Out:
#    0
# 0  3
# 1  3
# 2  2
# 3  3
# 4  1

# %% [markdown]
# ## Saving model as My_Predictions.csv

# %%
y_pred.shape
# Out:
# (1000,)

# %%
X_test.shape
# Out:
# (1000, 12)

# %%
ans = pd.DataFrame([ids.T, y_pred.T], index=['id', 'price_range']).T

# %%
ans.head()
# Out:
#    id  price_range
# 0   1            3
# 1   2            3
# 2   3            2
# 3   4            3
# 4   5            1

# %%
ans.to_csv('My_Predictions.csv')

# %% [markdown]
# ## Conclusion: Support Vector Machine works best here in this case because it performed best in k-fold cross validation
